# %% [markdown]
# # 01_hello_world - 环境测试实验
#
# 本 notebook 用于验证 Jupyter 环境与常用库（numpy、pandas、matplotlib）是否安装正确。

# %%
import sys
print(f"Python: {sys.version}")
# Out:
# Python: 3.12.9 | packaged by conda-forge | (main, Mar  4 2025, 22:37:18) [MSC v.1943 64 bit (AMD64)]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 设置中文字体，避免绘图时中文显示为方框或报 Glyph missing 警告
plt.rcParams["font.sans-serif"] = ["Microsoft YaHei", "SimHei", "SimSun", "KaiTi"]
plt.rcParams["axes.unicode_minus"] = False  # 解决负号显示异常

print("numpy:", np.__version__)
print("pandas:", pd.__version__)
print("matplotlib:", plt.matplotlib.__version__)
print("\n环境检查通过。")
# Out:
# numpy: 2.3.5
# pandas: 2.2.3
# matplotlib: 3.10.3
#
# 环境检查通过。

# %% [markdown]
# ## 简单计算示例

# %%
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
df = pd.DataFrame({"x": x, "sin(x)": y})
df.head(10)
# Out:
#           x    sin(x)
# 0  0.000000  0.000000
# 1  0.063467  0.063424
# 2  0.126933  0.126592
# 3  0.190400  0.189251
# 4  0.253866  0.251148
# 5  0.317333  0.312033
# 6  0.380799  0.371662
# 7  0.444266  0.429795
# 8  0.507732  0.486197
# 9  0.571199  0.540641

# %% [markdown]
# ## 简单绘图示例

# %%
plt.figure(figsize=(8, 4))
plt.plot(x, y, label="sin(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("正弦曲线 - 环境测试")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
